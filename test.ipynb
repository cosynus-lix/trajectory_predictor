# %%
import cv2

map = cv2.imread('maps/gmapping/new_map.pgm')
map = map[900:1550, 750:1400]

# save map
cv2.imwrite('map.png', map)
# Out:
# True

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('test2.png')
img2 = cv2.imread('test3.png')
centerline = cv2.imread('centerline.png')
org = cv2.imread('map.png')

rays = img-img2
centrays = centerline+rays
org[np.where((org==[254,254,254]).all(axis=2))] = [255,0,255]
cv2.imwrite('selected_zone_for_medial_axis.png', org)
# org[np.where((rays==[255,255,255]).all(axis=2))] = [0,0,255]
# org[np.where((centerline==[255,255,255]).all(axis=2))] = [255,0,0]
# cv2.imwrite('isolated_centerline.png', org)

plt.imshow(org)

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

l = cv2.imread('test/output.png')
d = -40
d2 = -15
l = l[880+d:1020-d, 810+d2:970-d2]

cv2.imwrite('map.png', l)
plt.imshow(l)
